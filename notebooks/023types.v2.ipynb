# %% [markdown]
# # Types

# %% [markdown]
# We have seen that Python objects have a 'type':

# %%
type(5)
# Out:
# int

# %% [markdown]
# ## Floats and integers

# %% [markdown]
# Python has two core numeric types, `int` for integer, and `float` for real number.

# %%
one = 1ten = 10one_float = 1.0ten_float = 10.

# %%
tenth = one_float / ten_float

# %%
tenth
# Out:
# 0.1

# %%
one // ten
# Out:
# 0

# %%
2 + 3
# Out:
# 5

# %%
"Hello " + "World"
# Out:
# 'Hello World'

# %% [markdown]
# With integers, we can be clear about what we want: divide an integer by an integer and return another integer, or divide an integer by an integer and return a floating point. Most other languages do not afford that kind of distinction! It can lead to hard-to-find bugs.

# %%
print(one // ten, one / ten)
# Out:
# 0 0.1

# %%
print(type(one // ten), type(one / tenth))
# Out:
# <class 'int'> <class 'float'>

# %% [markdown]
# The divided by operator `/` means divide by for real numbers. Whereas `//` means divide by integers for integers, and divide by floats for floats

# %%
10 // 3
# Out:
# 3

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3.0
# Out:
# 3.0

# %%
str(5)
# Out:
# '5'

# %%
10 / float(3)
# Out:
# 3.3333333333333335

# %%
x = 5

# %%
str(x)
# Out:
# '5'

# %%
x = "5.2"int(float(x))
# Out:
# 5

# %% [markdown]
# I lied when I said that the `float` type was a real number. It's actually a computer representation of a real numbercalled a "floating point number". Representing $\sqrt 2$ or $\frac{1}{3}$ perfectly would be impossible in a computer, so we use a finite amount of memory to do it.

# %% [markdown]
# *Supplementary material*:* [Python and floating point](https://docs.python.org/3.6/tutorial/floatingpoint.html)* [Floating point guide](http://floating-point-gui.de/formats/fp/)* Advanced: [What Every Computer Scientist Should Know About Floating-Point Arithmetic](http://docs.oracle.com/cd/E19957-01/806-3568/ncg_goldberg.html)

# %% [markdown]
# ## Strings

# %% [markdown]
# Python has a built in `string` type, supporting manyuseful methods.

# %%
given = "James"family = "Hetherington"full = given + " " + family

# %% [markdown]
# So `+` for strings means "join them together" - *concatenate*.

# %%
print(full.upper())
# Out:
# JAMES HETHERINGTON

# %%
2 * 4
# Out:
# 8

# %% [markdown]
# As for `float` and `int`, the name of a type can be used as a function to convert between types:

# %%
ten
# Out:
# 10

# %%
one
# Out:
# 1

# %%
type(ten)
# Out:
# int

# %%
print(ten + one)
# Out:
# 11

# %%
print(float(str(ten) + str(one)))
# Out:
# 101.0

# %% [markdown]
# We can remove extraneous material from the start and end of a string:

# %%
5
# Out:
# 5

# %%
"    Hello  ".strip()
# Out:
# 'Hello'

# %% [markdown]
# ## Lists

# %% [markdown]
# Python's basic **container** type is the `list`

# %% [markdown]
# We can define our own list with square brackets:

# %%
[1, 3, 7]
# Out:
# [1, 3, 7]

# %%
type([1, 3, 7])
# Out:
# list

# %% [markdown]
# Lists *do not* have to contain just one type:

# %%
various_things = [1, 2, "banana", 3.4, [1,2] ]

# %% [markdown]
# We access an **element** of a list with an `int` in square brackets:

# %%
one = 1two = 2three = 3

# %%
my_new_list = [one, two, three]

# %%
middle_value_in_list = my_new_list[1]

# %%
middle_value_in_list
# Out:
# 2

# %%
[1,2,3][1]
# Out:
# 2

# %%
various_things[2]
# Out:
# 'banana'

# %%
index = 2various_things[index]
# Out:
# 'banana'

# %% [markdown]
# Note that list indices start from zero.

# %% [markdown]
# We can quickly make a list with numbers counted up:

# %%
count_to_five = list(range(5))print(count_to_five)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# We can use a string to join together a list of strings:

# %%
name = ["James", "Philip", "John", "Hetherington"]print(" -> ".join(name))
# Out:
# James -> Philip -> John -> Hetherington

# %% [markdown]
# And we can split up a string into a list:

# %%
"Ernst Stavro Blofeld".split("o")
# Out:
# ['Ernst Stavr', ' Bl', 'feld']

# %% [markdown]
# We can an item to a list:

# %%
name.append("Jr")print(name)
# Out:
# ['James', 'Philip', 'John', 'Hetherington', 'Jr']

# %% [markdown]
# Or we can add more than one:

# %%
name.extend(["the", "third"])print(name)
# Out:
# ['James', 'Philip', 'John', 'Hetherington', 'Jr', 'the', 'third']

# %% [markdown]
# ## Sequences

# %% [markdown]
# Many other things can be treated like `lists`. Python calls things that can be treated like lists `sequences`.

# %% [markdown]
# A string is one such *sequence type*

# %%
print(count_to_five[1])print("James"[2])
# Out:
# 1m

# %%
print(count_to_five[1:3])print("Hello World"[4:8])
# Out:
# [1, 2]o Wo

# %%
print(len(various_things))print(len("Python"))
# Out:
# 56

# %%
len([[1, 2], 4])
# Out:
# 2

# %%
print("John" in name)print(9 in count_to_five)
# Out:
# TrueFalse

# %% [markdown]
# ## Unpacking

# %% [markdown]
# Multiple values can be **unpacked** when assigning from sequences, like dealing out decks of cards.

# %%
mylist = ['Goodbye', 'Cruel']a, b = mylistprint(a)
# Out:
# Goodbye

# %%
a = mylist[0]b = mylist[1]
