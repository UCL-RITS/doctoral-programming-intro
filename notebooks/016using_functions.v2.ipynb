# %% [markdown]
# # Using Functions

# %% [markdown]
# ## Calling functions

# %% [markdown]
# We often want to do thing to our objects that are more complicated than just assigning them to variables.

# %%
len("pneumonoultramicroscopicsilicovolcanoconiosis")
# Out:
# 45

# %%
len([3,5,15])
# Out:
# 3

# %% [markdown]
# Here we have "called a function".

# %% [markdown]
# The function `len` takes one input, and has one output. The output is the length of whatever the input was.

# %% [markdown]
# Programmers also call function inputs "parameters" or, confusingly, "arguments".

# %% [markdown]
# Here's another example:

# %%
sorted("Python")
# Out:
# ['P', 'h', 'n', 'o', 't', 'y']

# %% [markdown]
# Which gives us back a *list* of the letters in Python, sorted alphabetically.

# %% [markdown]
# The input goes in brackets after the function name, and the output emerges wherever the function is used.

# %% [markdown]
# So we can put a function call anywhere we could put a "literal" object or a variable.

# %%
name = 'Jim'

# %%
len(name) * 8
# Out:
# 24

# %%
x = len('Mike')y = len('Bob')z = x + y

# %%
print(z)
# Out:
# 7

# %% [markdown]
# ## Using methods

# %% [markdown]
# Objects come associated with a bunch of functions designed for working on objects of that type. We access these with a dot, just as we do for data attributes:

# %%
"shout".upper()
# Out:
# 'SHOUT'

# %%
"WhiSpER".lower()
# Out:
# 'whisper'

# %% [markdown]
# These are called methods. If you try to use a method defined for a different type, you get an error:

# %%
x = 5x.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2f7864fa034f> in <module>()
#       1 x = 5
# ----> 2 x.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %% [markdown]
# If you try to use a method that doesn't exist, you get an error:

# %%
x = 5x.wrong
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8f1e8a62ff4e> in <module>()
#       1 x = 5
# ----> 2 x.wrong
#
# AttributeError: 'int' object has no attribute 'wrong'

# %% [markdown]
# Methods and properties are both kinds of **attribute**, so both are accessed with the dot operator.

# %% [markdown]
# Objects can have both properties and methods:

# %%
z = 1 + 5j

# %%
z.real
# Out:
# 1.0

# %%
z.conjugate()
# Out:
# (1-5j)

# %% [markdown]
# ## Functions are just a type of object!

# %% [markdown]
# Now for something that will take a while to understand: don't worry if you don't get this yet, we'lllook again at this in much more depth later in the course.If we forget the (), we realise that a *method is just a property which is a function*!

# %%
z.conjugate
# Out:
# <function complex.conjugate>

# %%
type(z.conjugate)
# Out:
# builtin_function_or_method

# %%
somefunc = z.conjugate

# %%
somefunc()
# Out:
# (1-5j)

# %% [markdown]
# Functions are just a kind of variable:

# %%
magic = sorted

# %%
type(magic)
# Out:
# builtin_function_or_method

# %%
magic(["Technology", "Advanced"])
# Out:
# ['Advanced', 'Technology']

# %%
def double(data):    return data * 2

# %%
double(5)
# Out:
# 10

# %%
double
# Out:
# <function __main__.double>

# %%
timestwo = double

# %%
timestwo(8)
# Out:
# 16

# %%
timestwo(5, 6, 7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-576707f347a8> in <module>()
# ----> 1 timestwo(5, 6, 7)
#
# TypeError: double() takes 1 positional argument but 3 were given

# %%
def timesten(input):    return 5 * double(input)

# %%
timesten(4)
# Out:
# 40

# %% [markdown]
# ## Getting help on functions and methods

# %% [markdown]
# The 'help' function, when applied to a function, gives help on it!

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:sorted(iterable, /, *, key=None, reverse=False)    Return a new list containing all items from the iterable in ascending order.        A custom key function can be supplied to customize the sort order, and the    reverse flag can be set to request the result in descending order.

# %%
help(z.conjugate)
# Out:
# Help on built-in function conjugate:conjugate(...) method of builtins.complex instance    complex.conjugate() -> complex        Return the complex conjugate of its argument. (3-4j).conjugate() == 3+4j.

# %% [markdown]
# The 'dir' function, when applied to an object, lists all its attributes (properties and methods):

# %%
dir("Hexxo")
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# Most of these are confusing methods beginning and ending with __, part of the internals of python.

# %% [markdown]
# Again, just as with error messages, we have to learn to read past the bits that are confusing, to the bit we want:

# %%
"Hexxo".replace("x", "l")
# Out:
# 'Hello'

# %% [markdown]
# ## Operators

# %% [markdown]
# Now that we know that functions are a way of taking a number of inputs and producing an output, we should look again atwhat happens when we write:

# %%
x = 2 + 3

# %%
print(x)
# Out:
# 5

# %% [markdown]
# This is just a pretty way of calling an "add" function. Things would be more symmetrical if add were actually written    x = +(2,3)    Where '+' is just the name of the name of the adding function.

# %% [markdown]
# In python, these functions **do** exist, but they're actually **methods** of the first input: they're the mysterious `__` functions we saw earlier (Two underscores.)

# %%
x.__add__(7)
# Out:
# 12

# %% [markdown]
# We call these symbols, `+`, `-` etc, "operators".

# %% [markdown]
# The meaning of an operator varies for different types:

# %%
[2, 3, 4] + [5, 6]
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# Sometimes we get an error when a type doesn't have an operator:

# %%
7 - 2
# Out:
# 5

# %%
[2, 3, 4] - [5, 6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-5b64b789ad11> in <module>()
# ----> 1 [2, 3, 4] - [5, 6]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %% [markdown]
# The word "operand" means "thing that an operator operates on"!

# %% [markdown]
# Or when two types can't work together with an operator:

# %%
[2, 3, 4] + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-67b01a5c24ab> in <module>()
# ----> 1 [2, 3, 4] + 5
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# Just as in Mathematics, operators have a built-in precedence, with brackets used to force an order of operations:

# %%
print(2 + 3 * 4)
# Out:
# 14

# %%
print((2 + 3) * 4)
# Out:
# 20

# %% [markdown]
# *Supplementary material*: [Python operator precedence](http://www.mathcs.emory.edu/~valerie/courses/fall10/155/resources/op_precedence.html)
