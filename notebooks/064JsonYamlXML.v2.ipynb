# %%
from pip import main as pippip(['install', 'pyaml'])
# Out:
# ...
# 0

# %% [markdown]
# # Structured Data

# %% [markdown]
# ## Structured data

# %% [markdown]
# CSV files can only model data where each record has several fields, and each field is a simple datatype,a string or number.

# %% [markdown]
# We often want to store data which is more complicated than this, with nested structures of lists and dictionaries.Structured data formats like Json, YAML, and XML are designed for this.

# %% [markdown]
# ## Json

# %% [markdown]
# A very common structured data format is JSON.

# %% [markdown]
# This allows us to represent data which is combinations of lists and dictionaries as a text file whichlooks a bit like a Javascript (or Python) data literal.

# %%
import json

# %% [markdown]
# Any nested group of dictionaries and lists can be saved:

# %%
mydata =  {'key': ['value1', 'value2'], 'key2': {'key4':'value3'}}

# %%
text = json.dumps(mydata)

# %%
with open('myfile.json', 'w') as f:    f.write(text)

# %% [markdown]
# Loading data is also really easy:

# %%
file_as_string = open('myfile.json').read()

# %%
file_as_string
# Out:
# '{"key": ["value1", "value2"], "key2": {"key4": "value3"}}'

# %%
mydata = json.loads(file_as_string)

# %%
mydata['key2']
# Out:
# {'key4': 'value3'}

# %% [markdown]
# This is a very nice solution for loading and saving python datastructures.

# %% [markdown]
# It's a very common way of transferring data on the internet, and of saving datasets to disk.

# %% [markdown]
# There's good support in most languages, so it's a nice inter-language file interchange format.

# %% [markdown]
# ## Unicode

# %% [markdown]
# **Supplementary Material**: Why do the strings come back with 'u' everywhere? These are [**Unicode Strings**](http://www.joelonsoftware.com/articles/Unicode.html), designed to holdhold all the world's characters.

# %% [markdown]
# ## Yaml

# %% [markdown]
# Yaml is a very similar dataformat to Json, with some nice additions:

# %% [markdown]
# * You don't need to quote strings if they don't have funny characters in* You can have comment lines, beginning with a #* You can write dictionaries without the curly brackets: it just notices the colons.* You can write lists like this:

# %%
# %%writefile myfile.yamlsomekey:    # Look, this is a list    - a list    - with values    - [1, 2, 4] # and another list of integers
# Out:
# Writing myfile.yaml

# %%
import yaml

# %%
yaml.load(open('myfile.yaml'))
# Out:
# {'somekey': ['a list', 'with values', [1, 2, 4]]}

# %% [markdown]
# Yaml is a very versatile format for ad-hoc datafiles, but the library doesn't ship with default Python, (though it is partof Anaconda and Canopy) so some people still prefer Json for it's univerality.

# %% [markdown]
# Because Yaml gives the **option** of serialising a list either as newlines with dashes, *or* with square brackets,you can control this choice:

# %%
print(yaml.dump(mydata))
# Out:
# key: [value1, value2]key2: {key4: value3}

# %%
print(yaml.dump(mydata, default_flow_style=False))
# Out:
# key:- value1- value2key2:  key4: value3

# %% [markdown]
# ## XML

# %% [markdown]
# *Supplementary material*: [XML](http://www.w3schools.com/xml/) is another popular choice when saving nested data structures. It's very careful, but verbose. If your field uses XML data, you'll need to learn a [python XML parser](https://docs.python.org/2/library/xml.etree.elementtree.html),(there are a few), and about how XML works.

# %% [markdown]
# ## Exercise:

# %% [markdown]
# Use YAML or JSON to save your maze datastructure to disk and load it again.

# %%
# %%writefile foo.txtWrite this text
# Out:
# Writing foo.txt

# %%
myfile = open('foo.txt', 'w')

# %%
myfile.write("Write THIS text")
# Out:
# 15
